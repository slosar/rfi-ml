# %% [markdown]
# ## Simulated Dataset for RFI Flagging Post NN Run
#
# Below are scripts to generate simulated ADC counts for radio telescopes (ie. bmx), which retain all waveform elements (ie. phase, amplitude). RFI can resemble quick bursts, oscillating signals, decays, etc. However, most data (at least what I've seen) is uncontaminated and the datasets you can generate below should reflect that.

# %%
# General Imports

# %load_ext autoreload
# %autoreload 2
import sys, os, torch, datetime, time
import numpy as np
sys.path.append("..")
import sim_rfi #.py file located in rfi-ml directory

# %% [markdown]
# ### Generating Training Dataset

# %% [markdown]
# ### Generating Test Dataset

# %%
# Generating training data

# %% [markdown]
# ### Plotting Distinct RFI Events from Test Set

# %% [markdown]
# ### Saving Data (.npy files)
